# %% [markdown]
# # Create all graphics that appear on the home page of keelingcurve.ucsd.edu

# %% [markdown]
# ### Import notebooks from the keelingcurve GitHub Repo
#
# Install the GitHub Repo here and then one can call notebooks to run as if they were local

# %%
# %%bash
# git clone https://github.com/sio-co2o2/keelingcurve_notebooks.git

# %% [markdown]
# ## **Run Notebooks**

# %% [markdown]
# ## Create graphics of various time intervals at Mauna Loa, Hawaii

# %% [markdown]
# ### Create the full CO<sub>2</sub> record at Mauna Loa, Hawaii

# %%
# %run create_graphic_full_mlo_record_keelingcurve.ipynb
# Out:
# Button(button_style='primary', description='Download Files', style=ButtonStyle())

# %% [markdown]
# ### Create the last week of the CO<sub>2</sub> record from Mauna Loa, Hawaii

# %%
# %run create_graphic_mlo_one_week_keelingcurve.ipynb
# Out:
# Button(button_style='primary', description='Download Files', style=ButtonStyle())

# %% [markdown]
# ### Create the last month of the CO<sub>2</sub> record at Mauna Loa, Hawaii

# %%
# %run create_graphic_mlo_one_month_keelingcurve.ipynb
# Out:
# Button(button_style='primary', description='Download Files', style=ButtonStyle())

# %% [markdown]
# ### Create the last 6 months of the CO<sub>2</sub> record at Mauna Loa, Hawaii

# %%
# %run create_graphic_mlo_six_months_keelingcurve.ipynb
# Out:
# Button(button_style='primary', description='Download Files', style=ButtonStyle())

# %% [markdown]
# ### Create the last year of the CO<sub>2</sub> record at Mauna Loa, Hawaii

# %%
# %run create_graphic_mlo_one_year_keelingcurve.ipynb
# Out:
# Button(button_style='primary', description='Download Files', style=ButtonStyle())

# %% [markdown]
# ### Create the last two years of the CO<sub>2</sub> record at Mauna Loa, Hawaii

# %%
# %run create_graphic_mlo_two_years_keelingcurve.ipynb
# Out:
# Button(button_style='primary', description='Download Files', style=ButtonStyle())

# %% [markdown]
# ## Create graphics of various time intervals of CO<sub>2</sub> from Mauna Loa, Hawaii and ice-core records

# %% [markdown]
# ### Create the last year of the CO<sub>2</sub> record at Mauna Loa, Hawaii

# %%
# %run create_graphic_icecore_start_1700_ce_keelingcurve.ipynb
# Out:
# Button(button_style='primary', description='Download Files', style=ButtonStyle())

# %%
# %run create_graphic_icecore_back_2K_ce_keelingcurve.ipynb
# Out:
# Button(button_style='primary', description='Download Files', style=ButtonStyle())

# %%
# %run create_graphic_icecore_back_10K_keelingcurve.ipynb
# Out:
# Button(button_style='primary', description='Download Files', style=ButtonStyle())

# %%
# %run create_graphic_icecore_back_800K_keelingcurve.ipynb
# Out:
# Button(button_style='primary', description='Download Files', style=ButtonStyle())
