# %% [markdown]
# # All graphics that appear on the home page of keelingcurve.ucsd.edu

# %% [markdown]
# ## Import notebooks from the keelingcurve GitHub Repo
#
# Install the GitHub Repo here and then can call notebooks to run as if they were local

# %%
# %%bash
# git clone https://github.com/sio-co2o2/keelingcurve_notebooks.git

# %% [markdown]
# ## Create all Keeling Curve over various time intervals

# %%
# %run plot_full_mlo_record_keelingcurve.ipynb
# Out:
# Button(button_style='primary', description='Download Files', style=ButtonStyle())

# %%
# %run plot_mlo_one_week_keelingcurve.ipynb
# Out:
# Button(button_style='primary', description='Download Files', style=ButtonStyle())

# %%
# %run plot_mlo_one_month_keelingcurve.ipynb
# Out:
# Button(button_style='primary', description='Download Files', style=ButtonStyle())

# %%
# %run plot_mlo_six_months_keelingcurve.ipynb
# Out:
# Button(button_style='primary', description='Download Files', style=ButtonStyle())

# %%
# %run plot_mlo_one_year_keelingcurve.ipynb
# Out:
# Button(button_style='primary', description='Download Files', style=ButtonStyle())

# %%
# %run plot_mlo_two_years_keelingcurve.ipynb
# Out:
# Button(button_style='primary', description='Download Files', style=ButtonStyle())

# %% [markdown]
# ## Create all Keeling Curve alongside Icecore data over various time intervals

# %%
# %run plot_icecore_start_1700_ce_keelingcurve.ipynb
# Out:
# Button(button_style='primary', description='Download Files', style=ButtonStyle())

# %%
# %run plot_icecore_back_2K_ce_keelingcurve.ipynb
# Out:
# Button(button_style='primary', description='Download Files', style=ButtonStyle())

# %%
# %run plot_icecore_back_10K_keelingcurve.ipynb
# Out:
# Button(button_style='primary', description='Download Files', style=ButtonStyle())

# %%
# %run plot_icecore_back_800K_keelingcurve.ipynb
# Out:
# Button(button_style='primary', description='Download Files', style=ButtonStyle())
